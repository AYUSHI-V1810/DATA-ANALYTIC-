# %% [markdown]
# FUNCTION

# %% [markdown]
# 1. WHAT IS DATA ANALYTIC?
#   - Data analytics is the process of collecting, cleaning, transforming, and organizing data to discover useful insights and inform decision-making. It uses various tools and techniques, including statistics and machine learning, to analyze past and present data to identify trends, make predictions, and solve problems. The goal is to convert raw data into actionable intelligence that can improve business operations, enhance customer experiences, and drive growth

# %% [markdown]
# 2. HOW MANY TYPES OF DATA?
#  - There are four main types of data analytics: descriptive, diagnostic, predictive, and prescriptive. These types are built upon one another, moving from understanding past events to making recommendations for the future.

# %%
#function#
...
this is answer
...
...
this is answer
